# %% [markdown]
# <a href="https://colab.research.google.com/github/dariushazimi/machinelearning/blob/master/Exercise_1_House_Prices_Question.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# In this exercise you'll try to build a neural network that predicts the price of a house according to a simple formula.
#
# So, imagine if house pricing was as easy as a house costs 50k + 50k per bedroom, so that a 1 bedroom house costs 100k, a 2 bedroom house costs 150k etc.
#
# How would you create a neural network that learns this relationship so that it would predict a 7 bedroom house as costing close to 400k etc.
#
# Hint: Your network might work better if you scale the house price down. You don't have to give the answer 400...it might be better to create something that predicts the number 4, and then your answer is in the 'hundreds of thousands' etc.

# %%
import tensorflow as tf
import numpy as np
from tensorflow import keras
model = tf.keras.Sequential([keras.layers.Dense(units=1, input_shape=[1])])

model.compile(optimizer='sgd', loss='mean_squared_error')
xs = np.array([1,2,3,4,5,6], dtype=float)
ys = np.array([10,15,20,25,30,40], dtype=float)

model.fit(xs, ys, epochs=100)
print(model.predict([7.0]))
# Out:
# Epoch 1/100
# 6/6 [==============================] - 0s 14ms/sample - loss: 427.3036
# Epoch 2/100
# 6/6 [==============================] - 0s 529us/sample - loss: 199.3110
# Epoch 3/100
# 6/6 [==============================] - 0s 322us/sample - loss: 93.7858
# Epoch 4/100
# 6/6 [==============================] - 0s 302us/sample - loss: 44.9420
# Epoch 5/100
# 6/6 [==============================] - 0s 296us/sample - loss: 22.3323
# Epoch 6/100
# 6/6 [==============================] - 0s 206us/sample - loss: 11.8644
# Epoch 7/100
# 6/6 [==============================] - 0s 330us/sample - loss: 7.0162
# Epoch 8/100
# 6/6 [==============================] - 0s 210us/sample - loss: 4.7690
# Epoch 9/100
# 6/6 [==============================] - 0s 295us/sample - loss: 3.7256
# Epoch 10/100
# 6/6 [==============================] - 0s 164us/sample - loss: 3.2393
# Epoch 11/100
# 6/6 [==============================] - 0s 289us/sample - loss: 3.0110
# Epoch 12/100
# ...
